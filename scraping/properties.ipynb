# %%
import requests
from bs4 import BeautifulSoup

# %%
r1 = requests.get("http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c1 = r1.content
sp1 = BeautifulSoup(c1, "html.parser")

# %%
props = sp1.find_all("div", {"class": "propertyRow"})
# props

# %%
cnt = 0
for prop in props:
    print(f"\n******** Property {cnt} ***********\n")
    price = prop.find('h4', {'class': 'propPrice'}).text.strip()
    print(price)
    address = prop.find_all('span', {'class': 'propAddressCollapse'})
    for add in address:
        print(add.text)
        
    secs = prop.find_all('div', {'class': 'secondaryDetails'})
    if secs:
        for info in secs:
            for detail in ([s for s in info.text.split('\n') if s]):
                print(detail)

    dets = prop.find_all('div', {'class': 'propertyDetails'})
    
    if dets:
        for info in dets:
            print(info.find('div', {'class': 'propertyMLS'}).text.replace(" ", "").replace("\n", ""))
            for detail in ([s for s in info.text.split('\n') if s]):
                if (detail.lower().startswith("lot size")):
                    print(detail)
                
                
    cnt += 1
#     print(prop)
# Out:
# ******** Property 0 ***********
#
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
# MLS#20156419
#
# ******** Property 1 ***********
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
# 4 Beds
# 4 Full Baths
# MLS#20152130
# Lot Size: 0.21 Acres
#
# ******** Property 2 ***********
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
# 5 Beds
# 3,154 Sq. Ft
# 3 Full Baths
# MLS#20156389
#
# ******** Property 3 ***********
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
# 4 Beds
# 3,076 Sq. Ft
# 3 Full Baths
# 1 Half Bath
# MLS#20160119
# Lot Size: Under 1/2 Acre, 0.23 Acres
#
# ******** Property 4 ***********
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
# 3 Beds
# 1,172 Sq. Ft
# 3 Full Baths
# MLS#20155008
# Lot Size: Under 1/2 Acre, 0.19 Acres
#
# ******** Property 5 ***********
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
# 4 Beds
# 1,932 Sq. Ft
# 2 Full Baths
# MLS#20160028
# Lot Size: 0.27 Acres
#
# ******** Property 6 ***********
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
# 4 Beds
# 1,676 Sq. Ft
# 3 Full Baths
# MLS#20156320
# Lot Size: Under 1/2 Acre, 0.43 Acres
#
# ******** Property 7 ***********
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
# 3 Beds
# 1,344 Sq. Ft
# 2 Full Baths
# MLS#20155756
# Lot Size: Under 1/2 Acre, 0.13 Acres
#
# ******** Property 8 ***********
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
# 3 Beds
# 1,920 Sq. Ft
# 2 Full Baths
# MLS#20156880
# Lot Size: Under 1/2 Acre, 0.14 Acres
#
# ******** Property 9 ***********
#
# $196,900
# 4 Minnies Lane
# Rock Springs, WY 82901
# 3 Beds
# 1,664 Sq. Ft
# 2 Full Baths
# MLS#20156365
# Lot Size: 2.02 Acres
